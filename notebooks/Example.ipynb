# %%
import statsmodels.datasets
import pandas as pd
from statsmodels.api import OLS
from statsmodels.tools import add_constant

from steps.forward import ForwardSelector
from steps.subset import SubsetSelector

# %%
data = statsmodels.datasets.webuse('auto')
data = pd.get_dummies(data, columns=['foreign']).fillna(0)
data.head()
# Out:
#             make  price  mpg  rep78  headroom  trunk  weight  length  turn  \
# 0    AMC Concord   4099   22    3.0       2.5     11    2930     186    40
# 1      AMC Pacer   4749   17    3.0       3.0     11    3350     173    40
# 2     AMC Spirit   3799   22    0.0       3.0     12    2640     168    35
# 3  Buick Century   4816   20    3.0       4.5     16    3250     196    40
# 4  Buick Electra   7827   15    4.0       4.0     20    4080     222    43
#
#    displacement  gear_ratio  foreign_Domestic  foreign_Foreign
# 0           121        3.58                 1                0
# 1           258        2.53                 1                0
# 2           121        3.08                 1                0
# 3           196        2.93                 1                0
# 4           350        2.41                 1                0

# %%
X = data.iloc[:, 3:]
y = data['mpg']

# %%
selector = ForwardSelector(normalize=True)
selector.fit(X, y)
# Out:
# ForwardSelector(normalize=True)

# %%
X.loc[:, selector.get_support()]
# Out:
#     rep78  weight  length  gear_ratio  foreign_Domestic
# 0     3.0    2930     186        3.58                 1
# 1     3.0    3350     173        2.53                 1
# 2     0.0    2640     168        3.08                 1
# 3     3.0    3250     196        2.93                 1
# 4     4.0    4080     222        2.41                 1
# ..    ...     ...     ...         ...               ...
# 69    4.0    2160     172        3.74                 0
# 70    5.0    2040     155        3.78                 0
# 71    4.0    1930     155        3.78                 0
# 72    4.0    1990     156        3.78                 0
# 73    5.0    3170     193        2.98                 0
#
# [74 rows x 5 columns]

# %%
selector = SubsetSelector(normalize=True)
selector.fit(X, y)
# Out:
# SubsetSelector(normalize=True)

# %%
X.loc[:, selector.get_support()]
# Out:
#     rep78  weight  length  gear_ratio  foreign_Domestic
# 0     3.0    2930     186        3.58                 1
# 1     3.0    3350     173        2.53                 1
# 2     0.0    2640     168        3.08                 1
# 3     3.0    3250     196        2.93                 1
# 4     4.0    4080     222        2.41                 1
# ..    ...     ...     ...         ...               ...
# 69    4.0    2160     172        3.74                 0
# 70    5.0    2040     155        3.78                 0
# 71    4.0    1930     155        3.78                 0
# 72    4.0    1990     156        3.78                 0
# 73    5.0    3170     193        2.98                 0
#
# [74 rows x 5 columns]

# %%
mod = OLS(endog=y, exog=add_constant(X)).fit()
mod.summary()
# Out:
# /Users/christophersantiago/opt/miniconda3/envs/steps/lib/python3.8/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.720
# Model:                            OLS   Adj. R-squared:                  0.681
# Method:                 Least Squares   F-statistic:                     18.33
# Date:                Fri, 06 Aug 2021   Prob (F-statistic):           1.29e-14
# Time:                        08:14:55   Log-Likelihood:                -187.23
# No. Observations:                  74   AIC:                             394.5
# Df Residuals:                      64   BIC:                             417.5
# Df Model:                           9
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               24.5703      6.137      4.004      0.000      12.310      36.830
# rep78                1.0021      0.357      2.809      0.007       0.290       1.715
# headroom            -0.0167      0.611     -0.027      0.978      -1.237       1.204
# trunk               -0.0772      0.154     -0.503      0.617      -0.384       0.230
# weight              -0.0037      0.002     -1.928      0.058      -0.008       0.000
# length              -0.0752      0.061     -1.229      0.223      -0.197       0.047
# turn                -0.1762      0.187     -0.941      0.350      -0.550       0.198
# displacement         0.0131      0.011      1.180      0.243      -0.009       0.035
# gear_ratio           3.7067      1.751      2.116      0.038       0.208       7.206
# foreign_Domestic    14.5168      3.016      4.814      0.000       8.493      20.541
# foreign_Foreign     10.0535      3.271      3.074      0.003       3.519      16.587
# ==============================================================================
# Omnibus:                       28.364   Durbin-Watson:                   2.523
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.945
# Skew:                           1.389   Prob(JB):                     3.18e-12
# Kurtosis:                       6.074   Cond. No.                     6.31e+18
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.82e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
mod = OLS(endog=y, exog=add_constant(X.loc[:, selector.best_support_])).fit()
mod.summary()
# Out:
# /Users/christophersantiago/opt/miniconda3/envs/steps/lib/python3.8/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.710
# Model:                            OLS   Adj. R-squared:                  0.688
# Method:                 Least Squares   F-statistic:                     33.25
# Date:                Fri, 06 Aug 2021   Prob (F-statistic):           5.22e-17
# Time:                        08:15:16   Log-Likelihood:                -188.63
# No. Observations:                  74   AIC:                             389.3
# Df Residuals:                      68   BIC:                             403.1
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               36.3580      8.237      4.414      0.000      19.921      52.795
# rep78                0.9040      0.342      2.647      0.010       0.223       1.586
# weight              -0.0030      0.002     -1.770      0.081      -0.006       0.000
# length              -0.1058      0.053     -1.990      0.051      -0.212       0.000
# gear_ratio           2.6905      1.511      1.780      0.079      -0.325       5.706
# foreign_Domestic     4.0123      1.320      3.040      0.003       1.379       6.646
# ==============================================================================
# Omnibus:                       24.257   Durbin-Watson:                   2.442
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.774
# Skew:                           1.252   Prob(JB):                     2.31e-09
# Kurtosis:                       5.576   Cond. No.                     6.92e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.92e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
